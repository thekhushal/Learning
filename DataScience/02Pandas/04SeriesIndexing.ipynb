# %% [markdown]
# # **Series Indexing**
# - Normal Indexing
# - .loc & .iloc Indexing
# - Boolean Indexing

# %%
import numpy as np
print("imported numpy sucessfully")
import pandas as pd
print("imported pandas sucessfully")
# Out:
# imported numpy sucessfully
# imported pandas sucessfully

# %%
# Sample dataset

x = pd.Series([12,13,14,35,46,57,58,79,9])
# x

# with 1 col
subs = pd.read_csv('../04CampusX_DataSet/datasets-session-16/subs.csv').squeeze()
# subs

# with 2 cols
vk = pd.read_csv('../04CampusX_DataSet/datasets-session-16/kohli_ipl.csv',index_col='match_no').squeeze()
# vk

# 
movies = pd.read_csv('../04CampusX_DataSet/datasets-session-16/bollywood.csv',index_col='movie').squeeze()
movies

marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks,name='nitish ke marks')
# marks_series

# %%
movies = pd.read_csv('../04CampusX_DataSet/datasets-session-16/bollywood.csv',index_col='movie').squeeze()
movies
