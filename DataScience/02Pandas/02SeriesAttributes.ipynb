# %%
import numpy as np
import pandas as pd

# %%
# smaple seires
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks,name='nitish ke marks')
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: nitish ke marks, dtype: int64

# %% [markdown]
# # **Series Attributes**
# An attribute tells you something about the python object, be it series or df or any other object
# - size
# - dtype
# - name
# - is_unique
# - index
# - values

# %%
marks_series.size
# Out:
# 4

# %%
marks_series.dtype
# Out:
# dtype('int64')

# %%
marks_series.name
# Out:
# 'nitish ke marks'

# %%
marks_series.is_unique
# Out:
# True

# %%
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
marks_series.values
# Out:
# array([ 67,  57,  89, 100])
