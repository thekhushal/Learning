# %%
# # Level 1 – Pandas Fundamentals (25 Questions)

# ### A. Understanding the Dataset

# 1. Display the first 10 rows.
# 2. Display the last 15 rows.
# 3. Find the number of rows and columns.
# 4. Display the names of all columns.
# 5. Display the data type of every column.
# 6. Find how much memory the DataFrame uses.
# 7. Display summary statistics for all numeric columns.
# 8. Display summary statistics for all columns (including object columns).

# ---

# ### B. Selecting Data

# 9. Display only the `Series_Title` and `IMDB_Rating` columns.
# 10. Display the first 20 movie titles.
# 11. Display the last 30 directors.
# 12. Select rows with index 50 to 75.
# 13. Select the first 5 rows and the first 4 columns.
# 14. Display a random sample of 10 movies.

# ---

# ### C. Filtering Rows

# 15. Find all movies released after 2015.
# 16. Find all movies with an IMDb rating greater than 8.5.
# 17. Find all movies longer than 180 minutes.
# 18. Find all movies directed by Christopher Nolan.
# 19. Find movies whose certificate is `"A"`.
# 20. Find movies that earned more than 100 million in Gross.

# ---

# ### D. Sorting

# 21. Sort movies by IMDb rating (highest first).
# 22. Sort movies by Gross (lowest first).
# 23. Sort movies by release year and then IMDb rating.

# ---

# ### E. Basic Analysis

# 24. Find:

# * Highest IMDb rating
# * Lowest IMDb rating
# * Average IMDb rating

# 25. Find:

# * Number of unique genres
# * Number of unique directors
# * Number of unique certificates

# ---

# ## Challenge Questions (Optional)

# These require combining multiple operations.

# 26. Find the highest-rated movie released after 2010.

# 27. Find the longest movie with an IMDb rating above 8.

# 28. Find the youngest movie (latest release year) among the top 50 highest-rated movies.

# 29. Find the first movie alphabetically.

# 30. Find the last movie alphabetically.

# ---

# ## Rules

# While solving these:

# * Try **not** to search the internet immediately.
# * Use only your notes or `df.info()` if you're unsure about column names.
# * If you're stuck for more than **10–15 minutes** on a question, look up the relevant method, understand it, and move on.
# * Don't memorize solutions—focus on understanding *why* a particular method is appropriate.

# This level is intentionally straightforward. Once you can complete these comfortably, Level 2 will introduce `value_counts()`, `groupby()`, missing values, string methods, and more analytical questions that are much closer to what you'll encounter in interviews and real projects.

# %% [markdown]
# ### A. Understanding the Dataset
#
# 1. Display the first 10 rows.
# 2. Display the last 15 rows.
# 3. Find the number of rows and columns.
# 4. Display the names of all columns.
# 5. Display the data type of every column.
# 6. Find how much memory the DataFrame uses.
# 7. Display summary statistics for all numeric columns.
# 8. Display summary statistics for all columns (including object columns).

# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv("")

# %%
# 1. Display the first 10 rows.
